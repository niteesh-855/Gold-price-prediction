# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Gold prediction\gold prices.csv")
df
# Out:
#             Date  Close/Last    Volume    Open    High     Low
# 0     08/17/2023      1915.2  146770.0  1922.4  1933.5  1914.2
# 1     08/16/2023      1928.3  124766.0  1933.1  1938.2  1922.0
# 2     08/15/2023      1935.2  161512.0  1939.4  1944.3  1927.5
# 3     08/14/2023      1944.0  117514.0  1945.6  1948.2  1934.2
# 4     08/11/2023      1946.6  119090.0  1944.9  1953.6  1942.7
# ...          ...         ...       ...     ...     ...     ...
# 2534  08/23/2013      1395.8  149116.0  1376.1  1399.9  1367.8
# 2535  08/22/2013      1370.8  134493.0  1365.6  1381.4  1354.5
# 2536  08/21/2013      1370.1  137350.0  1371.0  1378.9  1359.2
# 2537  08/20/2013      1372.6  130096.0  1364.9  1378.0  1351.6
# 2538  08/19/2013      1365.7  116056.0  1377.1  1384.1  1362.0
#
# [2539 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date           0
# Close/Last     0
# Volume        28
# Open           0
# High           0
# Low            0
# dtype: int64

# %%
df['Volume'] = df['Volume'].fillna(df['Volume'].mean())

# %%
df.isnull().sum()
# Out:
# Date          0
# Close/Last    0
# Volume        0
# Open          0
# High          0
# Low           0
# dtype: int64

# %%
x = df[df.isnull().any(axis=1)]
x
# Out:
# Empty DataFrame
# Columns: [Date, Close/Last, Volume, Open, High, Low]
# Index: []

# %%
# Total number of missing values in the entire DataFrame
total_missing = df.isnull().sum().sum()
print(f'Total missing values: {total_missing}')
# Out:
# Total missing values: 0

# %%
# Check if there are missing values in a specific column (e.g., 'Close/Last')
missing_in_column = df['Close/Last'].isnull().sum()
print(f'Missing values in Close/Last column: {missing_in_column}')
# Out:
# Missing values in Close/Last column: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2539 entries, 0 to 2538
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2539 non-null   object
#  1   Close/Last  2539 non-null   float64
#  2   Volume      2539 non-null   float64
#  3   Open        2539 non-null   float64
#  4   High        2539 non-null   float64
#  5   Low         2539 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 119.1+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
df = df.sort_values(by='Date', ascending=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2539 entries, 0 to 2538
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2539 non-null   datetime64[ns]
#  1   Close/Last  2539 non-null   float64
#  2   Volume      2539 non-null   float64
#  3   Open        2539 non-null   float64
#  4   High        2539 non-null   float64
#  5   Low         2539 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 119.1 KB

# %%
df
# Out:
#            Date  Close/Last    Volume    Open    High     Low
# 2538 2013-08-19      1365.7  116056.0  1377.1  1384.1  1362.0
# 2537 2013-08-20      1372.6  130096.0  1364.9  1378.0  1351.6
# 2536 2013-08-21      1370.1  137350.0  1371.0  1378.9  1359.2
# 2535 2013-08-22      1370.8  134493.0  1365.6  1381.4  1354.5
# 2534 2013-08-23      1395.8  149116.0  1376.1  1399.9  1367.8
# ...         ...         ...       ...     ...     ...     ...
# 4    2023-08-11      1946.6  119090.0  1944.9  1953.6  1942.7
# 3    2023-08-14      1944.0  117514.0  1945.6  1948.2  1934.2
# 2    2023-08-15      1935.2  161512.0  1939.4  1944.3  1927.5
# 1    2023-08-16      1928.3  124766.0  1933.1  1938.2  1922.0
# 0    2023-08-17      1915.2  146770.0  1922.4  1933.5  1914.2
#
# [2539 rows x 6 columns]

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df
# Out:
#            Date  Close/Last    Volume    Open    High     Low  Day  Month  \
# 2538 2013-08-19      1365.7  116056.0  1377.1  1384.1  1362.0   19      8
# 2537 2013-08-20      1372.6  130096.0  1364.9  1378.0  1351.6   20      8
# 2536 2013-08-21      1370.1  137350.0  1371.0  1378.9  1359.2   21      8
# 2535 2013-08-22      1370.8  134493.0  1365.6  1381.4  1354.5   22      8
# 2534 2013-08-23      1395.8  149116.0  1376.1  1399.9  1367.8   23      8
# ...         ...         ...       ...     ...     ...     ...  ...    ...
# 4    2023-08-11      1946.6  119090.0  1944.9  1953.6  1942.7   11      8
# 3    2023-08-14      1944.0  117514.0  1945.6  1948.2  1934.2   14      8
# 2    2023-08-15      1935.2  161512.0  1939.4  1944.3  1927.5   15      8
# 1    2023-08-16      1928.3  124766.0  1933.1  1938.2  1922.0   16      8
# 0    2023-08-17      1915.2  146770.0  1922.4  1933.5  1914.2   17      8
#
#       Year
# 2538  2013
# 2537  2013
# 2536  2013
# 2535  2013
# 2534  2013
# ...

# %%
x = df[['Day','Month','Year']]
y = df[['Close/Last']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
model.score(x_test,y_test)
# Out:
# 0.9968746460622921

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Squared Error:", mse)
print(rmse)
# Out:
# Mean Squared Error: 246.53230562893714
# 15.70134725521785

# %%
new_data = pd.DataFrame({'Day': [3], 'Month': [1], 'Year': [2000]})  # Example input
predicted_value = model.predict(new_data)

print("Predicted 'Close/Last' value:", predicted_value)
# Out:
# Predicted 'Close/Last' value: [1373.069]

# %%
import pickle

with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
